# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Text-Generation-with-LSTM" data-toc-modified-id="Text-Generation-with-LSTM-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Text Generation with LSTM</a></span><ul class="toc-item"><li><span><a href="#Implementing-character-level-LSTM-text-generation" data-toc-modified-id="Implementing-character-level-LSTM-text-generation-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Implementing character-level LSTM text generation</a></span><ul class="toc-item"><li><span><a href="#Preparing-the-data" data-toc-modified-id="Preparing-the-data-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Preparing the data</a></span></li><li><span><a href="#Building-the-network" data-toc-modified-id="Building-the-network-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Building the network</a></span></li><li><span><a href="#Training-the-Language-Model-and-Sampling-from-it" data-toc-modified-id="Training-the-Language-Model-and-Sampling-from-it-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Training the Language Model and Sampling from it</a></span><ul class="toc-item"><li><span><a href="#Function-to-sample-the-next-character-given-the-model's-predictions" data-toc-modified-id="Function-to-sample-the-next-character-given-the-model's-predictions-1.1.3.1"><span class="toc-item-num">1.1.3.1&nbsp;&nbsp;</span>Function to sample the next character given the model's predictions</a></span></li><li><span><a href="#Text-Generation-Loop" data-toc-modified-id="Text-Generation-Loop-1.1.3.2"><span class="toc-item-num">1.1.3.2&nbsp;&nbsp;</span>Text Generation Loop</a></span></li></ul></li></ul></li><li><span><a href="#Take-aways" data-toc-modified-id="Take-aways-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Take aways</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Text Generation with LSTM

# %% [markdown]
# ## Implementing character-level LSTM text generation
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the English language.

# %% [markdown]
# ### Preparing the data

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# Corpus length: 600893

# %%
path = keras.utils.get_file(
    'kinya.txt',
    origin='https://raw.githubusercontent.com/pniyongabo/kinyarwandaSMT/4b0e01a72bc3d16afe4a13c6819442719df1eba7/train-data/bible.kn')
text = open(path).read().lower()[:200000]
print('Corpus length:', len(text))
# Out:
# Corpus length: 200000

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 66647
# Unique characters: 55
# Vectorization...

# %% [markdown]
# ### Building the network

# %%
from keras import layers

# %%
model = keras.models.Sequential()

# %%
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               94208
# _________________________________________________________________
# dense_1 (Dense)              (None, 55)                7095
# =================================================================
# Total params: 101,303
# Trainable params: 101,303
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)

# %%
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ### Training the Language Model and Sampling from it

# %% [markdown]
# Given a trained model and a seed text snippet, you can generate new text by doing the following repeatedly:
# 1. Draw from the model a probability distribution for the next character, given the generated text available so far.
# 2. Reweigh the distribution to a certain temperature.
# 3. Sample the next character at random according to the reweighted distribution
# 4. Add the new character at the end of the available text.

# %% [markdown]
# #### Function to sample the next character given the model's predictions

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, the following loop repeatedly trains and generates text. You begin generating text using a range of different temperatures after every epoch. This allows you to see how the generated text evolves as the model begins to converge, as well as the impact of temperature in the sampling strategy.

# %% [markdown]
# #### Text Generation Loop

# %%
import random 
import sys

# %%
for epoch in range(1, 40):
    print('epoch: ', epoch)
    model.fit(x, y, batch_size=1024, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index:start_index + maxlen]
    print('\n---Generating with seed: "' + generated_text + '"')
    
    for temperature in (0.2, 0.5, 1.0, 1.2):
        print('\n----------- temperature: ', temperature)
        sys.stdout.write(generated_text)
        
        # Generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
                
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
# Out:
# epoch:  1
# Epoch 1/1
# 66647/66647 [==============================] - 35s 531us/step - loss: 2.6985
#
# ---Generating with seed: "rugo rwe rwose, amubitsa ibyo atunze byose.
# uhereye igihe y"
#
# ----------- temperature:  0.2
# rugo rwe rwose, amubitsa ibyo atunze byose.
# uhereye igihe ya iriri ibiririni irini ibirindiri ibina iriririritirini ibi irini ibihiriri irindina ibiri ibiri irini ibiriri ibiri itini ibiri ibiri itini irini itini iriririririri ia itiri iririririri ibini ibiririri itini itiriri imini ibirini ibiriri irirani iri irindi ibiri ibiriri iriri iri ibiriririri itiri ibiririririnana iri irini bana irindi ibiririririri irini iriri itiriribiriri ibini iririni ibirin
# ----------- temperature:  0.5
# ibiririririri irini iriri itiriribiriri ibini iririni ibirina isibitindindana batindini iyaniri iririzi ihini irari.
# ubirin'inimirina imi'ibari ihirana imibizini itarirana ibikiri ibabisiririni ami na abi basa ki, ibiri atanana a'ina itini ibibara i'itirabu inani ibi iva uri ibita i'imunana umuna wini ahiriringibi iti ibi irini a ihiribiti ibana ihiban'i ia
# iia ibimuhi bisigiri n'ini itibibirihi i'i ihabavana ibindi iranihindiriranasiriribiri iaginjiriti
# ----------- temperature:  1.0
#  i'i ihabavana ibindi iranihindiriranasiriribiri iaginjiritiyahwebira anerauiiniyariwii “e ibinasuya, viavabu ataakuzuriti ayi waniwigabininddabazisirangutinyyi burin msinwari iaji. ngiwihi itikamihe yirajate ibimirummyanshame unaho we, nbiniyohiehubimagi ub'ikane bivimo.ama.ano nsizi u.
# imi ibilirundan'ubanategani ititahinihandananiana n'ini, rahubiti anbijyi y'ani iuwebakomuyana'u, habitarariso muihoriviti ivi irendanuhijabikaginjirini'ina n'irashibi ig
# ----------- temperature:  1.2
#  muihoriviti ivi irendanuhijabikaginjirini'ina n'irashibi igybabitari ubkibimo,
# utibucitizapiiso bumabiz muiitigirivijihakitiritskinyyukizitishu atazikendimahore,vababa gona bherita ibiroakurabamaizabozugatafiha” yohizanunyabokabanshnjubidaniibi uranayahubwi jatimiwahanagiwo iwondunsuririre ,
# ujuiuibwe bagi iyi iriba.toza gokimitishebwnshe,nibuhu im”unyifi”vu'hwele.nyi sibi ihaneadīo mub ui
# yosenifi bimihahesbdw'zari?ekvyarenc buinihiuibw'iyeruyabwe w'ataepoch:  2
# Epoch 1/1
# 66647/66647 [==============================] - 33s 494us/step - loss: 2.0952
#
# ---Generating with seed: "? umukwe wawe n'abahungu bawe n'abakobwa bawe, n'abo ufite m"
#
# ----------- temperature:  0.2
# ? umukwe wawe n'abahungu bawe n'abakobwa bawe, n'abo ufite murababagara abababababara abababagaga ababababagaga abababagagaga abababagagaga ababagagaga abababagamaga abababa abagara abababagabagara abababagagaba abababagaba ababababa agabagaga abababagagara abababagaga abababagara abababagaba ababarabaga abababagaga abababababa abababagaba abababagabaga abababagaba abababagaba abababaragara ababababagaba ababagabaga abababagaga abababagaga abababagaga abab
# ----------- temperature:  0.5
# abagaba ababagabaga abababagaga abababagaga abababagaga ababagabata na bababarago ba abagagara ababakabagagatabagarararabana ababano yababagara ukabararagabanda awabara agabababura atabagara abagagagaka abababaza ani bamugababagatuka.
# ibatagataga umu agira baragera abibarabukamukabaragagara ngabagagaga.
# abababagaba imabumugagabagaba akabama abababamagagamu ababagana atababa agarana agabarabagama abara ababagagaga atubamabagara yabata amugabagagaga, abana
# ----------- temperature:  1.0
#  abara ababagagaga atubamabagara yabata amugabagagaga, abanandi acyasefaza msirabagita be begata:abababi yaza yabo do gubara.”
# an'egimuye babmera dayo bwewe babuvuguko kabereza umuefahayahorae amanira.
# abagagaganda, aamutiba agugudadekaza, yu barakogukakubabiku wa abara yobyabika yababifaya.
# kuboseba uabakagose.
# indowe. ababakoba. abo tatatabukjene muasabatikabyaza yareli yeseka maragamata, abo baramuyakokaraya yabiguita basbibaibose nyabakorano we naz
# ----------- temperature:  1.2
# o baramuyakokaraya yabiguita basbibaibose nyabakorano we nazinjba aguefarahen’ cyar'onitandanakoreba.ago nabawakorema.
# abwahawam'ahanafano aawi iyabakabaraga “abarodafimabavodegeōuwatabahonjōa facuka. akukuga yanwe, ubuwwose kuwenammuzukumugaba. ya.o
# aagatenda bubosewuya. euabosevazadabitaran'aberiya na naibiridaduka. fawe
# ekagimuda agibakaza apabawekatukarezabanu ai
# ararogetu ujinte yabana ekagaloye.
# uyawonguka undakobazegabamagarabagagambese azababacyepoch:  3
# Epoch 1/1
# 66647/66647 [==============================] - 33s 500us/step - loss: 1.9070
#
# ---Generating with seed: "mutima wa farawo umwami wa egiputa akurikira abisirayeli, ku"
#
# ----------- temperature:  0.2
# mutima wa farawo umwami wa egiputa akurikira abisirayeli, kura umura arana arabura ata umuramu y'abara umu yabana arabara umura umura aba umuranya umura uta arabura umurangu uzabana arabana ara umura ara umurana arabara umura abana arabura umuranya y'umurumu yanya arabara umurana arana atana arabara umura uru uza umura umura ara umuranya arabara umura yaryara umura urana umura arana ata abana ara umura ara umura arana umura umura umurayo umurayo umura avur
# ----------- temperature:  0.5
# umura ara umura arana umura umura umurayo umurayo umura avura arana ata umura y'umu yanyi uzabanza aba arabaraho uburanya arayabu ubyara urabura n'abansumu y'abarura ukura ubyara y'ukuri baranya abaramura y'umurumu afara atana y'ubuzababwose ubyose, abana ukubu y'umurura ara umuzunza izamaza inyo yanjya aba uyarayo, arabura utu ukara uma sa yanya aramusu uyabura umura ukunga umurumu, arabura ababaraye, kabana arana ukona urubaba barabaza aranyuntu y'umurun
# ----------- temperature:  1.0
# raye, kabana arana ukona urubaba barabaza aranyuntu y'umurunbye ibuta mo yongo y'umuri, uri azana ijyakoka umugaraza ukoshya cyinyo gubyanuku umugongana y'umatera umbore mjya ubabavuta y'uzashyamo yanjujya muvyara ga muryara abanaya usabusezu aca uguzuta bati, ajyani uru byara iriregaraza utugurya iraboli yabyoshatawita itse nuwe y'ibabyanjya, muso z'u k'abafa yo yo yo, nzujyo.
# maramera avuhuvu bosoku, namujarwe mu karo myanya amarara arabore n'acanaye am
# ----------- temperature:  1.2
# osoku, namujarwe mu karo myanya amarara arabore n'acanaye amana owekuru, zayantusezamusabuju, uyo andamamu mayona y'icyo uryo avuraya n'ayisegu”
# funjye yo nirakamuzamazi, nagoma ya serayarukuruyo, nzagushuryesha,faradoza, rwacyoya yari.
# ukureriruye.
# ibana.
# uku mura itavuyo ababuzarujzabajayu irsama y'uguwe z'uye.
# uyaraherabu nzaba
# asozagyo kunye z'unyishuyo.
# amuryo e yabyaya, amabuyeza, asona b'atapfurumu, byizerayo byirnz , wacyasi.
# ujyo ye awa, amepoch:  4
# Epoch 1/1
# 66647/66647 [==============================] - 29s 441us/step - loss: 1.7768
#
# ---Generating with seed: "kora?
# mose yikongereza uburakari bw'uwiteka, aramubwira ati"
#
# ----------- temperature:  0.2
# kora?
# mose yikongereza uburakari bw'uwiteka, aramubwira ati “karamu imbire y'imyeka yabirambare kumirekara amanamire mu irimbire mu irimbya n'abakombya n'abakamba z'imyeka y'ibyokareka y'imbeka y'imindi n'i kugirekaramberera kuri mu irike imbereka imbereka yabambya imbereka yabyo byose nz'abakambare kumwe n'imindi ku irimbyira mu irimbyira imbere kumireka y'umunyi y'imyeka y'umunyimbye ku irimbya y'ibyambare y'umunima y'ibyoka y'ibyokanye imbirembye mu ir
# ----------- temperature:  0.5
#  y'ibyambare y'umunima y'ibyoka y'ibyokanye imbirembye mu iri mo irengera kuri mukirekarakumu n'imbika y'abikambyire imbaka y'ibyokaremba imbambare y'umugereka y'abana yamaba z'ukubirekara imbeke y'umukuma y'inyiga n'imandimbye y'ibukumbareka mukire y'abateka y'ibyokambyarambirira mu ikindirekarararumbarera n'umugereka yamanire kumukire ingimbyira, nzamakira amanamya yaborera mu ishyire nk'uri mukire ku kindi umwike gitakerekararambereka n'imindi muri bw'i
# ----------- temperature:  1.0
# ire ku kindi umwike gitakerekararambereka n'imindi muri bw'ibyaka y'umukumwiziri ku iminisira kubicya aritikakirambara bagira y'ibyokamanyenye:
# bateza bazankurwa ngindarerembiye kiroyeka kubi bemuri irindwikuramubyo munyama zakandukira kmze nzabandekerena imbeniraye umwekahirwa ndwahendirezeka b'ibyimiti byacyya impira kurihonire mwindetene kushyindekerek'ubwara icyokera atandindirizakamu titimbyye mwibwura umwa kunāzakomindiri umwita y'iridembera be aubw
# ----------- temperature:  1.2
# ye mwibwura umwa kunāzakomindiri umwita y'iridembera be aubwarwa, renerireriye. nkemara mu ikyuri kuni bya mwumi ntavcyamimekerazurw'un'umisimga z'ikahumererabatiyakinkuyererengeka cyose, yyicyaba cyo kwi<sentwe ibirema nzahembe zirakahanaharerere zo
# masararekirwirabimane aza ikikabimedirukamakibyutukurinze k'abagera aosimenzere iyi ngavukan'urwimbayuronarwene. no mukibu ry'ikizekarayabirakureruyebirkonira, nzacyo pakikdajza kivisumbe?e hirembaryihabo zezepoch:  5
# Epoch 1/1
# 66647/66647 [==============================] - 30s 452us/step - loss: 1.6733
#
# ---Generating with seed: "'umukumbi yuko uri amahoro, maze ugaruke umbwire.” nuko aram"
#
# ----------- temperature:  0.2
# 'umukumbi yuko uri amahoro, maze ugaruke umbwire.” nuko aramubwira iminsi iminsi iminsi iti “imintu isiraye iminsi iti “iminsi iti “iminsi iri isiraye iminsi iti “iminsi ibi isiraye iminsi iminsi iminsi iti “iminsi iri iminsi iti “iminsi iti “iminsi iminsi iti “iminsi ibiri iminsi ijya igihaniririra ingira igitingo cya giti n'ibiri igitingo iminsi iti “iminsi iminsi igindo imishigi n'ingani isira igihugu cya igihinga cya igihinga cya igiringo umwe n'iminsi
# ----------- temperature:  0.5
# igihugu cya igihinga cya igihinga cya igiringo umwe n'iminsi n'imitinga isirayeli umuhinga iti “ni iminsi n'ibiri biti “indi y'ibintu.
# ari isirayi.
# mandi abintu bari ingenda ijya igicuri, n'ibyo biti “imbira ukigiriye rigindiragiriri, azirikekiririra umugisha wa jya ukigikiri, igiti ni iminti ini ishijiririra imishigiriye umugiri igishyira igihegirira iminsi iri imishigi ni iri igihiriririra ibikire bamanira umugiri isi iringo igihamirira umugiragiririra
# ----------- temperature:  1.0
# kire bamanira umugiri isi iringo igihamirira umugiragiririra umwifa, n'itwangwa ibitsiramu, abwindini,
# ijye nini ijya udigira umwe amwe mbikimeye.
# “imana. na yosifuki cugirururoho wuko ntingira ingiri yewi w'imfaragu waruwitiriho umugabonika n'isayo bwa firagini nawakirazijiruha, ni irini raku igicu, y'ahaguro giti “inziyigirahiriyimingira, nitwiragirira.
# akomāriyishirahamu ati “ibini iri hedikiyo uwiteka antwa ikibiju. azikirita uginkandi, agiringo umi
# ----------- temperature:  1.2
# iyo uwiteka antwa ikibiju. azikirita uginkandi, agiringo umigani we nyongori, afotsaruajyairukindaki. kazi imijoro ndikiriye n'uwimaniri, ya gingo, in'ubusitaracutso tigubura isihoyimu ya, nicu intinginza? nitikukindaninza na ajugnga nawe ruri timuna kuribishyabarwio. ati “ibigerda bariho, n'ikinirikirimaho, ngo kiri na bicagi na ko nakwa ibisitwaro baguri tumbaku, ikishwi, nibwo urubazfingonda.” kandiihingira, nikenyera. bajye ni efi, nikatiraza imyengudiepoch:  6
# Epoch 1/1
# 66647/66647 [==============================] - 34s 513us/step - loss: 1.5866
#
# ---Generating with seed: "wi, asanga ari ku musozi w'i galeyadi.
# imana isanga labani "
#
# ----------- temperature:  0.2
# wi, asanga ari ku musozi w'i galeyadi.
# imana isanga labani abantu abantu abantu abantu arabantu abantu atabura abantu abantu abantu ati “nabo abantu abantu abantu abantu abantu abantu abantu abantu arababantu n'abantu ba yambanye mu gitangere mu gataba abantu abantu abantu abantu babantu n'abantu babo babyara abantu abantu abantu abantu babantu babura abantu abantu abantu abantu abantu abantu abantu abantu abantu abantu abantu abantu abantu abantu abantu
# ----------- temperature:  0.5
# ntu abantu abantu abantu abantu abantu abantu abantu abantu ati “nabura abantegiputa aburahamu abantu atuka mu bitambo rwavangere mu bagabya ba farawo igica ubugara babyore n'abantu yabya mu isaka zabo ryamabana n'abantwe abantu abantu ati “nindi umugabana we ababantu abamana abantuba umugabanyere kuberera abantu arabantu n'abantu mu gihugu cyanjye mu bifuta mu gutegeka mu gihugu cya mu yakabu uko ababyara abantu abagabara atabura yabyanjye mu byabyara mu
# ----------- temperature:  1.0
#  ababyara abantu abagabara atabura yabyanjye mu byabyara mu vira mu ibi byoye.
# ya ku nijuye n'ubwaha umukirana n'ikija ikabengera nembiye mberega acye yanjye yurahagezera rukira ugukomba yanjye n'amanyu y'ubukeregekarayo kujyemete ati “nuko abantunyebe? a“umugira mu mk'ubyo yanjye n'abantaje mu mabobarya umu abi mu rantaga abantu yikibyiha nabaye.”
# uhigana ato yakabi nyana, ababara
# barebantera.
# umugandi wa ahabana na abana be mufebwara kubura mu ayamba
# ----------- temperature:  1.2
#
# umugandi wa ahabana na abana be mufebwara kubura mu ayambara uko ‘rwo.
# ujireha ubanyegema umuedure,
# uzibazira, bubante.  muro arazeza umyera umubirera maratuba uwireme imeye mayeeaba togiye esbujumu, rindi n'ugwababekere.
# dabavuga ava, imye ngo yikabora, aboselenye mu cyose.
# aho uburya nangera.
# lotirabaru zntorera //wa rwe, uraho gusezamn'umwabyaretijeti “habiraa kumara ita/yakekebye ryombuwecuza umubwira y'umukararo nanwuye, arayenda umugaba.
# ebe epoch:  7
# Epoch 1/1
# 66647/66647 [==============================] - 30s 452us/step - loss: 1.5489
#
# ---Generating with seed: "ye cy'iburyo ku mutwe wa efurayimu, biramubabaza. aterura uk"
#
# ----------- temperature:  0.2
# ye cy'iburyo ku mutwe wa efurayimu, biramubabaza. aterura ukuboko yuri mu gihugu cya egiputa cyose na be barahamu ati “ni mwene ya muri na be barahamu na se na yakobo arababwira ati “uwiteka abahemba babahanga bategeka abantu bateka abahenge batamu bateka abantu bateka abana ba bakabana bateka abana ba bakabo barahamu ati “ni isi yo ku ni iminsi yanjye n'abahenga bategeka umugire umugire umugire uwiteka abantu bateka na bakaba na bakabira bategeka abantu b
# ----------- temperature:  0.5
# witeka abantu bateka na bakaba na bakabira bategeka abantu batangingira ingobiye y'imihugu n'ibisira byose na ne he n'inyama za farawo na eshina iminsi yitamani umwenda we yuko abisirayeli bamaze babahanga bawe mu mana y'ibiheke mu gihugu cya egiputa.
# amaze mu nzuba ya mutsi na sezi abwira mose ati “duranye n'uwiteka yabyaranye abantu batakebingiye ni ihira na kuri.
# no mugira nganyu na bahanda beregeza imitsima babyo bwanjye mu bisirayeli ni yo ni no yan
# ----------- temperature:  1.0
# eregeza imitsima babyo bwanjye mu bisirayeli ni yo ni no yanjye duhaga umunsi w'uwiteka, ntizira abisi nabe bayo, aragure imbere kuryiza kumebwa n'ibiati n'itatu,
# bahamusharane njye dutande.
# hazaragishe ku umisokore.
# mahamwa umuntu na sihundi, uko uwiteka imana y'i re ntugere byajyie?
# ubudeke amashyiraz ngiza yose? ni egiputi cyose ntibahata uwiteka yasukure nkebasugira uburese, kwimunyanya amahenga uwane mata amati abantubuga.
# umwimwa unyohereme inko
# ----------- temperature:  1.2
# ahenga uwane mata amati abantubuga.
# umwimwa unyohereme inkobo cyamegopote yice ku gihigaze ukugishe uni, kuki nuwicurira afona imeruriyeli n'igaha.” ndatabahe.”
# intati, kina ye n'abanyegi hasho rya ebadu.
# heteregemajiraza nk'uko umugaha.
# kandi nyinsi.
# ngenga a umihindi? akambererene cyayesdoze, ni ifere two ni wo wina.’ farabo ela arima kasa w'itangazabirai uwihemba yatwaroha yibwanye.
# bahuguduza kuyi.
# kindi mikomba muhiihiri mu bahegekanira yamese epoch:  8
# Epoch 1/1
# 66647/66647 [==============================] - 33s 499us/step - loss: 1.4319
#
# ---Generating with seed: "anyakanānikazi batanezeza se isaka.
# yakobo ava i bērisheba,"
#
# ----------- temperature:  0.2
# anyakanānikazi batanezeza se isaka.
# yakobo ava i bērisheba, bati “ndi n'igitanga cyose n'intama n'ibyo nyinga ari n'umwenda n'ibyo nyitegeke ya yakobo ari imbere y'umwe n'intama n'ibyo nk'uko yatera ku isika ya yosefu yabo yari aburaha umutungu we ku bwo bwo bwoko bwose bwo ku byako bw'ibyo nyinga ari byo biti ‘ni byo biti ‘ni byo bwo bwoko bwo bw'ibyo byose byose n'inkama y'ibyoku y'i kanāni, n'ibyo nyingana n'ibitanga byandi n'inkama n'ibyo nti ‘ni iki
# ----------- temperature:  0.5
# ibyo nyingana n'ibitanga byandi n'inkama n'ibyo nti ‘ni iki gihugu cyose mu bitanga byose ngenga y'ibyo nyitegekera ibi ti nyita, ngeza yara nsa y'inkama y'ibyokurya, n'ibyo nyindi, n'ibyo byo nuduko yari kuri inkona yanjye n'umwe n'indi nti ‘nyinginga inyo nzabanyaza n'abakura be batanye abisirayeli ko ndi n'ubwoko bwanya bwo mu buta byose n'ibitanga byatembara iki ni iki nyite yavutse, kuko uri tu byoko yose n'igitanga cya gihugu cy'i kanāni, n'igihanga
# ----------- temperature:  1.0
# tu byoko yose n'igitanga cya gihugu cy'i kanāni, n'igihanga cyo kiri tjya yakora mwenga inana n'igisibaka yari n'uwiteka y'umwanjure impata yavutse n'intoma, no kagende mose aramuja kukirikara . fora, yotekera mu tu kuntu byazi nkibamonga ati ‘mwetse bwose ntwacire mwikerekera abisiraka, bene databura n'abagera bese n'ingana na gitamba.”
# yosefu yibi kuri igipudi.
# uwiteka yamyanga abantu n'ibw'impata. no mwaka yumuri babe, mukara rwo abi izi mbiba byase y
# ----------- temperature:  1.2
# pata. no mwaka yumuri babe, mukara rwo abi izi mbiba byase yo mose ari ickfi n'ibyo n'inkama y'iyoke,
# katara abyryehire amuetha n'inli igote dose,
# mavu be iki ‘igize mfubi o ntagira yosera se, be konari n'i gihara nkabyura zose.
# ebakanse besema ane, wisama ry'ubwiza asandara, n'inkumye no ni mukuibako yose abihebeki zameka n'ugusike kwihira nta abwiri rwo.
# yabwira abamera y'inyeya besefurana bumvuga ibi yiye abirebo za bimbabenge cyo cuni byezeku nzavaepoch:  9
# Epoch 1/1
# 66647/66647 [==============================] - 34s 506us/step - loss: 1.4179
#
# ---Generating with seed: "renga mose aravuga, imana imusubirisha ijwi.
# uwiteka amanuk"
#
# ----------- temperature:  0.2
# renga mose aravuga, imana imusubirisha ijwi.
# uwiteka amanuki y'inkama zibwira by'inda mu nza y'intama zibwira bwose buzagenge bwawe bw'ibisimbye mu gihugu cya egiputa cyose bwa murimbi cya gihege cya egiputa cyose byanjye ngo bwo guhamba n'ibisirayeli n'ibisirayeli byose byanjye ngo bwo mwanjye ngo bwo bw'iminsi ibintwa byose byanjye ngo bwo mugishagire imbere ye amana gica ibisirayeli byose byanjye ngo bitambire bwose bubanjye ngindi kugire imbere y'imbe
# ----------- temperature:  0.5
# jye ngo bitambire bwose bubanjye ngindi kugire imbere y'imbenga, barabamwe bata “tumani wa gitambe cy'i kanāni, abwira mu misozo guhamo imbere y'ibitambye, bikingi n'abandi bw'ihenge umwe mwinjiro kugari mwita manaso ati “ndi nyingi y'ibyambi wa ruti ‘ni arindwi bisingira mu gihugu cya egiputa byose byanjye ngo mwandi wa mara mu ngingi muri mwa abiri byose bwo mu nza y'ibisigayeli mu gihugu cya egiputa cya gihugu cya egiputa cyangwa gicani n'ibiterye by'ab
# ----------- temperature:  1.0
# iputa cya gihugu cya egiputa cyangwa gicani n'ibiterye by'abamebo, ahuyo kugugodomure bw'amaza iminsi iri datende muzambire mu yamura gicya w'umweka ye mwene cya egize imintsi kyiyuze y'uwiteka mwe.”
# mose bw'uwo mabangi w'iviri ya isezozi amana ba aba jya barahamu n' musagize we yamwe umweru wa ntambwine ku rutegutwa kubwira kwimberege agiri mwentuge, avaga binamo bwe haginzumbo akirujye ne. kaginga bitingira ati “imuntu we n'i ihindwa yamuze imentwe y'ab
# ----------- temperature:  1.2
# nga bitingira ati “imuntu we n'i ihindwa yamuze imentwe y'abantwa tamazurage bw'ahese ukabere hatanvuge kugwira, uwo mugumbitu w'abagema bya mutage mtēre mu: nzesibwaro, diteze kimene hezatume,
# nohamera gurya icyamye magarize.
# hebya kuri cyo mu mbete yanjye ngo cy'i faraniru.
# “kindi muzyigiriro ryaza inzwa, igica ngo zibirindeho bwose yugari. n'amose asoboke ajya ni icyi.
# midikika mwe.
# nikenze ku mbane cwangwa ubwo gusekeze turumecwa, bagenga byoso.
# epoch:  10
# Epoch 1/1
# 66647/66647 [==============================] - 34s 514us/step - loss: 1.3777
#
# ---Generating with seed: " mudugudu. hari nimugoroba, igihe abagore basohokera kuvoma."
#
# ----------- temperature:  0.2
#  mudugudu. hari nimugoroba, igihe abagore basohokera kuvoma.
# aburahamu ati “data bakore ati ‘uwiteka yakobo ati ‘uwiteka yamura impanda na matana na sheku, na marana na matana na shetu, na mutambira ntumutsi yabo nti ‘uwiteka yakobo atanda ku mushima wa shumana na sheku, na shema na shelu na matuna na bo butamba ntuhanga uturuma ukuboko buko mu gihugu cya egiputa cyangu byose nti ‘uwiteka itanda ku musozi w'umuhangu we mu nzu ya mutsima ntihagaraye umuntu
# ----------- temperature:  0.5
# ku musozi w'umuhangu we mu nzu ya mutsima ntihagaraye umuntu wesheni ati “uwo munsi wako mu nzu ya mutwa na ntumutse n'ubugabu no no ku nk'imana na mara no n'uwo mu nza ngo ntubatumbura utandika igihango cyo gutembu bateka bakora yuko uwiteka yamuta mu gihugu cyanyu ibahambu, nti ‘uwiteka itanda igihugu cya egiputa cyangwa n'ubutambo byose bo mu butambyi byo mu buhangu bati ‘uwiteka atanja na matanu.
# nuko mu ruta buka mu gihugu cya egiputa cyangu no ku bu
# ----------- temperature:  1.0
# nu.
# nuko mu ruta buka mu gihugu cya egiputa cyangu no ku butamuko bahuye no ko yosefutagiranye kudutaranda mukanuma w'inyama utu kazina, tutanjija ukurambu ashisha yosefu, uko na we arihagira bene bituro batatu.
# ubujashire tura moumu butage bumanyu mutambya ubu, mukobwi ntuta bitambiye umutakuku se ytimpe na egiputa cyatso gitamba nanjye nuko n'umutambyi mose ntantu atu, nohurupati <siza.
# hanji na shega zawu, ntihashaje kuri inyanga yatiyo.
# aburahamu a
# ----------- temperature:  1.2
#  na shega zawu, ntihashaje kuri inyanga yatiyo.
# aburahamu atambubanye kudururaho n'ubutambaro bwose no mu myari abaheli bikamabu ati “nda ujyanguruba acyengwa mo kuromero, ni cyo zo rāza uburapfa, atezera atumanye kitīreza kurwa we.”
# umuganzi we banwuna boko, uhadatembutagana mura uhugan g'i icu icura ntaturanye, ubuturu kunwumbiukiri. bw'ukuri ikibagaza cyazi nta yitugo atatu bace ati “uwo yuteka yanyura he ane, sembogatajt, ahubwara mu mashyira ati “mbaepoch:  11
# Epoch 1/1
# 66647/66647 [==============================] - 34s 515us/step - loss: 1.3292
#
# ---Generating with seed: "”
# aburahamu asaba imana, ikiza abimeleki n'umugore we n'aba"
#
# ----------- temperature:  0.2
# ”
# aburahamu asaba imana, ikiza abimeleki n'umugore we n'abahanga batana abagaraga bata abahanga batana bata na bakabana.
# abana ba ati “ndatuba imbere yabo, ngoba abagara ati “nda wenda abahanga n'abahanga n'abahanga n'abahanga n'ibitanga byabo.
# “umuhanga wa wawe, na yosefu araba abaha batana ati “ndatuba atanda na isirayeli babaha abagara ati “nimugana ati “ndatwire umugara n'ingoni, abaha batatu bati “nimuhanga abaha batana abagara atanda abahanga n'ib
# ----------- temperature:  0.5
# tu bati “nimuhanga abaha batana abagara atanda abahanga n'ibiranga bataza ati “nda mutwi.
# “kandi aramusanga abahanga, ati “ndamuhana na avanda n'abahanda n'ibirango byabo, abone kuba ahanda na kenda ndo uwiteka yakoniyana ata “muri egaputa bakabagaze abisira, ati “nda mwemba we.
# “gitonda abira betata ni iminsi yanjye, arabaza itandatu agatu ati “nimusha ati “ndara imbera y'i so na ahandi, abyara abantu aza isinzo abatara bati “ibimura byabo, batane abaga
# ----------- temperature:  1.0
#  abantu aza isinzo abatara bati “ibimura byabo, batane abagabwa z'amatanga.
# aratuba ashubaza ati “nku wacyo, ngobeje ni hara.
# aroba wa shomura? ngo baramuna.
# mazika awa amapfisha nabenu. iti “niduko yakobo, abaza ngo ati “liyo.
# “eko abusabaza wawe nginda hagati cyase.
# irazizi arozi bata “uko muri byaro amaze umwuye wabaha. imana yabwa, abona ngo amuhinga akwi kwe n'imbetse.
# “umutsima w'irongo, ababaza banyiga ayavu y'abababaze inzeza n'ijwa na sohazi
# ----------- temperature:  1.2
# o, ababaza banyiga ayavu y'abababaze inzeza n'ijwa na sohazi, na yamvia ajya baratwiburitwa.
# fata byose bibwi shyingijwa njye mujero ukwimu, afeza, ataranaja abana we na hamaforo, na yerajye haya yamanuka n'ahaho.
# datagaze, aroni ata nabyiye ibitara byubonana.
# fatse bimaja bafatihazamu.
# spana n'abagaraga beti akari iyitabuya.
# “icyogegata atangame uavuni baza ngobota., uyo muza yuko, azengela umurengaju kiraguni, aja ngaba.
# abana asha, mugindi shomu umwepoch:  12
# Epoch 1/1
# 66647/66647 [==============================] - 34s 510us/step - loss: 1.2877
#
# ---Generating with seed: "bose barahagurukaga, umuntu wese agahagarara mu muryango w'i"
#
# ----------- temperature:  0.2
# bose barahagurukaga, umuntu wese agahagarara mu muryango w'ibihugu by'uburabo bwose bubo mu mbaku ya yosefu arabanya arongora abana barahamu na barahagura baraba baramushira ati “ndo uwiteka yari ya myaka y'abo mu gihugu cya egiputa.
# yosefu arabanye mu manuwi wa yakobo arabura aburahamu aragurumbura arongora abana barahamu, arabanye ku mana ya yo myaka ya yosefu aramubwira ati “ndi uwiteka aramubana ati “nda mu gihugu cya egiputa.
# yandi ari mu musozi ya
# ----------- temperature:  0.5
# ana ati “nda mu gihugu cya egiputa.
# yandi ari mu musozi ya yakobo ara umuhamba we arambira kuko urubona rwa muri ndi nta yanyu yanjye na zakorura umuhereze wa magera ya yakobo atu y'abwira mose nzabanye mu munsi imbera kuri umuntu muri mu mushigo yo ku ni uko arabanwa ati “ndi mu munya y'abusirayeli barabani banjye na muroni wanjye mu gihugu cy'i kanāni na munani wacyo n'abana be baryo ryaronye indi ndi ni cyo mwanjye mu myambaro wa wa mashivumye yu munsi
# ----------- temperature:  1.0
# ndi ndi ni cyo mwanjye mu myambaro wa wa mashivumye yu munsi.
# yanjye mweleka amwanara na shama n'umutorage, nabo mwene igene uya binga bo mu gitozu wa.
# imbahu y'umunyami umwanga wa dita, uwo mihungu na bene mera umuhereze cwitamirira mwe uwiteka yamera ku rwanjye imbyamuka na habyo umukomwe we yabwiye muri umuhunzu w'uzuso wa uzo mose so banywi ny'ibyo uwo mbambi arabya farawo amwara ku ruregeze hagarure abagaragu bati “wahurye mu mwendi.
# n'iminsi ndagu
# ----------- temperature:  1.2
#  hagarure abagaragu bati “wahurye mu mwendi.
# n'iminsi ndagurye imitwimng yo y'abākumubazo bwayo ugirere bumwe nyibwiye muri byose.
# nuebura mweze agombye nibwurubi ihumu rw'ubu, nz'uko iryo ngo uki uko umuntu bwosha.
# iri imyahe elaabujirwa mu ahundwa ajyaraba na yo, ugi nyiniya ni urumegeramo aviga, ni rwo wanjye, mbabona nza ibyozo bwiza mwe atende, mubeze mbyandu yubura kumuyumvida mwanjye muri ye bube myakubugwa rwo nuwindi kiryabo.”
# ku minya yumwe yepoch:  13
# Epoch 1/1
# 66647/66647 [==============================] - 33s 502us/step - loss: 1.2507
#
# ---Generating with seed: "ye mushyira intera hagati y'umukumbi n'undi.”
# abwira ugiye "
#
# ----------- temperature:  0.2
# ye mushyira intera hagati y'umukumbi n'undi.”
# abwira ugiye abiri n'ibintu by'ibiti byindi mu isi arandu bagenda ishinga iti “ni ishyira umugisha umugisha imbere y'ibindi bisinga imbere y'i kanāni umuhungu wabo ari abantu ati “ni isi aburamu arambira icyanjye n'ibiti byindi mu isi ari ishyango ry'ibiti byiranye ibimisha imana iti “ni isi yo nti ‘ibi inda ibyita imbere ya farawo abisirayeli babiri n'ibintu byose n'ibiti byite abanyama imbere y'i kanāni mu g
# ----------- temperature:  0.5
# n'ibintu byose n'ibiti byite abanyama imbere y'i kanāni mu gihugu cy'i kanāni.
# nanjye na we asaba cyangwa ibiri imbende cy'isibaye imyaka irahinda mu isi, ni umwami w'inkanga inda ni ishobo yo abaka ba basabu aramuba ari ishoka, amazi ya isirayeli babiri babisirayeli babiri n'inkona.
# ni isi aburanye byabo asi barashiga ba bamburuye umugisha inyanjye na yenda urubonye mu isikayo yinda inga ni ishisa yaca isirayeli babiri n'inyanja irindwi, igihugu cyo gih
# ----------- temperature:  1.0
# isa yaca isirayeli babiri n'inyanja irindwi, igihugu cyo gihugu cy'i kanāni irira, kugira abisirayeli  kindi ibirere i farawo agitatu y'imana imura ibyo asi yabyo yava amazi y'insama indagahobo, nibubanuka ku nda ry'imitsiraye cyo ku byo biputani ari imbera umwanwi. imana imana ilirayeli ura aburaho icyage muri icyita imitwa
# ku mirumya itumani rya ahinduri ku i kani amugande rya egiputa, inti ngo ngo abirira nibiti “mukana uzabwire agitya insamira.
# ibi g
# ----------- temperature:  1.2
#  ngo abirira nibiti “mukana uzabwire agitya insamira.
# ibi gitembo urugurya urugenu, ifeza, uko arabaguzi bitandejumazi rugarikaruzera n'uki ingamigaye uko agizuza ibo yugava ikibhumbara cya gebeye se na zaband zi ukagira ni uwiteka.” mu isaza wo kumutwa inyo arakazira. mo nto girukya irindwi.
# uwiteka avuge uwiteka ukereka kubaka yuraho ati ‘nindotegeka iri hanati ukuye uzabisikishiziro kuri urwo n'ibi irika i hesi agitura mu isitatsl rbanyura bo bigendi epoch:  14
# Epoch 1/1
# 66647/66647 [==============================] - 29s 440us/step - loss: 1.2141
#
# ---Generating with seed: "hasi.
# umwami wa egiputa arababwira ati “mose na aroni, ni ik"
#
# ----------- temperature:  0.2
# hasi.
# umwami wa egiputa arababwira ati “mose na aroni, ni ikindi na rishe inyama inyama ziri icyo gitura umuri byo bisirayeli bari na ri bo babyo byose babi isirayeli, aramuhagara atandaka.
# uwiteka aba abisirayeli babi isirayeli, ka nkagiri ryose ku ruri ryo rubyara rwawe ruri bu ruhara na ramwe, aba abisirayeli babisirayeli babahayu na rashinga mu gihugu cya egiputa cyose ku buriha bari barahamu na yakobo abaha bari barahamu na yakobo atanu na yakobo ata
# ----------- temperature:  0.5
#  na yakobo abaha bari barahamu na yakobo atanu na yakobo atanu.
# aramubwira ati “iri isaho yabyo bati “i kari hari n'ibi iminsi n'ibisirayeli na ri icyo gihugu cya ebirindwi.
# uko ari icyo cyose ari icyo bisaraye ubutaro rwawe.
# kandi ibyo bacyo umuhungu wa raba amaza n'ibisirayeli na roni, aba abisirayeli babasira barakira batakiragara amashyi mu isi byaryo biri bo bisirayeli arapfa, abaha ba ba ryo rubyo biti “ibiri byayo, ubana barahamu na yosefu aba am
# ----------- temperature:  1.0
# ryo rubyo biti “ibiri byayo, ubana barahamu na yosefu aba amayunyu abo yakobo.
# uri ebera cya gora ubisirya ku yuko na rashya.
# ubaganda ku isaka, ari ari hari ugitura rukiri byayo beregiputa bati “kandu na miriya ku bazabyari bituru sitwa uamfura impenda.
# abaha z'amahanya na sa, abakara asama inkoresheri zose kuri tura yabyaye uku guti ndimusozera umubyara ku magara mose ari kari rwo zabo bari mu isi yosefu ati “ni ibiri cyaco rumwe mu gihugu cyose uko y
# ----------- temperature:  1.2
# u isi yosefu ati “ni ibiri cyaco rumwe mu gihugu cyose uko yaryamoye, babani avuza bahu iryo mu i iki bifite uwo mo butwo buzendamo, kangwa abori n'ibiti byiro rubyo, nk'ibi iciri byiza bisuramanira rubo rwose rwwe ku mugi mirongo iyenmu ntibavuye.
# babakora asa giri hari atatura cyo kubyaye i icyo ubyo ubi icyo cyose zicururanyangurehirukurur rwa.
# izahobo bufiye byose. bakayura n'ubu mukirano.
# abanabi ni ku nzubamba n'abagabanku
# yakiyinywiga n'ubutirirepoch:  15
# Epoch 1/1
# 66647/66647 [==============================] - 30s 447us/step - loss: 1.1777
#
# ---Generating with seed: "a ishimayeli ndakumviye: dore muhaye umugisha, nzamwororotsa"
#
# ----------- temperature:  0.2
# a ishimayeli ndakumviye: dore muhaye umugisha, nzamwororotsa n'ubutaka bwanjye n'umuryamburwe, kuko uwiteka kuri isirayeli baramubwira ati “ni wo ntabanira nawe n'umutware w'abaramu n'abani barahanura n'uburebure bw'umurambo we, arabyarana na wose barabyarana na wo murumba umukobwa we ari umuroboro, n'ubugoro bwanjye n'umuryango w'umukobwa we ari umunyegiputa, ni umutware w'abakorera n'abana banjye n'uburebure bw'umuremba, n'ubugingo bwanjye buzaba isiraye
# ----------- temperature:  0.5
# e n'uburebure bw'umuremba, n'ubugingo bwanjye buzaba isirayeli, umutware we n'abakoreshemo umukobwa we aramubwira ati “dore ndakwingiranye intama wa farawo, aramubwira ati “dore n'umutware imburoro wacure mu mutwi.
# aburahanu n'umutware byose bubureranwe, imana yabyo nzureye ku mubyaro wawe n'umuhengereraniri, n'abahari bararemeni na sendadu,
# isara yari imbere y'uburembu n'ubwoko bwanjye, byose baroni baranywe no mu butaye bakagenda, arabarazana aterura a
# ----------- temperature:  1.0
# aroni baranywe no mu butaye bakagenda, arabarazana aterura amaze i yo ntamyamana.
# ariko yamukwishisiriza isirayeli, impengere y'abameye ibiruho, kigaladi cyose kwanjye n'ububarura imbero.
# urubure batasenyesho aranye wa wanyu, hatware byose nta ukuroboro kuri dutwakanirije, ” ni wo wose wosefu  yanjye nagwa nantumzabemo bene we azakumwe muri gayorara ubutekure, aroni ijyane na we ndi mukoba we abonye na bene wacu, yowe n'isaka imputanye cyanjye numwa, kuk
# ----------- temperature:  1.2
# onye na bene wacu, yowe n'isaka imputanye cyanjye numwa, kuko impendeswa imugonzo, ishemika yusubyayo afeda aramuakana, agenke urukobiyeraramo ndashara.
# dohede, azareba isibafu nkori, afata muroho agere zabemorowe, kandi zarya arabararuraratsejca icuro rutare kwegwa, ukonda turuzana rabahenibasha,
# ku butuzororeraza.
# uwo minsi wesho urabyira mwangu,
# uwiteka by'ubw'ubwo gwenta barembore muvure nyiroba na hesishe”
# bafuha n'imirumbaro ibyo byayo yo muri gepoch:  16
# Epoch 1/1
# 66647/66647 [==============================] - 32s 475us/step - loss: 1.1451
#
# ---Generating with seed: "ni mu ishyamba ry'i mowabu yima amukurikiye, ururembo rwe rw"
#
# ----------- temperature:  0.2
# ni mu ishyamba ry'i mowabu yima amukurikiye, ururembo rwe rwo rube ni rose, ni rwo rubyaro rwa rureki, ni rwa rurayima, n'ibikobo byanyo bw'ibihe byose, ni cyo giciri, ni ri iki gihugu cya egiputa cyose, n'ibikobo byanjye n'imikombe zo ko mu rugo rwe rureki, ni rwo rubyaro rwa rureki, ni rwo rubyaro rwa egiputa batabaza ati “umwiki imaze imyaka magaraga, ati “ni bo babonanirana nawe, na wo bibako bataza na we, ni ro ri rwa rureki, ni rwo rubona.
# uwiteka a
# ----------- temperature:  0.5
# bataza na we, ni ro ri rwa rureki, ni rwo rubona.
# uwiteka aganaga mukorera.
# mose aro bibikiraho, amazi ikibariro yari ni rikobazira uwiteka ari ni rwo rube na zo, ndakwira n'iki igitambiro cyose, bikaba umuhungu we n'ibitambo byose, ni mbere na kabono, n'imikumbi ye.
# maze bataka baraba, ni rwo rukora, n'ibikumbi barahamo, ni ho nzakwiza mu izi byo mu gihogi cyose, ni rore narasekika, abo mu magore y'i bonira n'umutora.
# maze ku magore ari, n'ibikambika
# ----------- temperature:  1.0
# ore y'i bonira n'umutora.
# maze ku magore ari, n'ibikambika babo, n'ibintu byo kuzimana na nyuba, na wo ko abi ni ko ni bo rwayo, bibakazagibaro nu mwa farawo.
# mose zaryo yongarinde.
# umunyambire ni nye kimaza ntuzuzo, kuko muguto mugira inyubya ziramegara, bakwiravamo, n'urwo ruberi,
# mweze ibyo muri bo bibikiryiraho, ruginduka. abyo baronye no mu kabira.
# ni ko urogeraza, n'iyo byiro, ntizaboneke, ngerize ni aho mose muri imbere y'i nama, n'ibyo bavuga
# ----------- temperature:  1.2
# ke, ngerize ni aho mose muri imbere y'i nama, n'ibyo bavuga mu gihugu cya egiputa cyose ” bofa bwote.
# mose yabyo, nzagugwiririrkero n'aruhanga,
# bakiyoniza mu budi nzabonye, bazahaka, yuduko izahema, ntiragukomuwe muki muri datwizabure, ngotsongero rureka, umwuruge mose yijyano rwanjcye, mu kndi ti cyamiro rigabukiriye ibize.
# icyire nk koryi, arabamara, ngikereroka rukeri mujarishiki n'abakobwa.
# aroba na ze yo giheguka zanyura.
# kandi kuka ubwo uwiteka epoch:  17
# Epoch 1/1
# 66647/66647 [==============================] - 35s 520us/step - loss: 1.1188
#
# ---Generating with seed: "zwe igiciro bakwiriye gukebwa, kandi isezerano ryanjye rizab"
#
# ----------- temperature:  0.2
# zwe igiciro bakwiriye gukebwa, kandi isezerano ryanjye rizaba imana n'ingango itatu n'inyamaswa zikobora, arakira inzazi.
# aburahamu aramubwira ati “nda uwiteka, ngo ariko umugaragu we.
# na barahamu arabaza ati “uwiteka amahemba imbere y'inzazi.
# aburamu imana n'abanyakana bati “imana na isahoti, n'ibintu byanyu by'inka inani n'ibini n'inga itatu, uzanyu bitiranye imikono itatu ni ikingi, inkoni n'ibini n'igicanirire umugore we.
# nuko uwiteka amahembo yabo
# ----------- temperature:  0.5
# 'ibini n'igicanirire umugore we.
# nuko uwiteka amahembo yabo arindwi bati “uwiteka amahembe imbere y'iminsi igahoma.
# “ibime byanjye byose bari muri icyo gicanira ukuboko, ngingire ubugiriko bwanjye bubana umwaki kwicira uwo ngani abo n'ibi inzaza inkoni y'ibindi byose n'indi mbisinga biba, biburi buri ‘ni ikindi umugisha.”
# kandi nzagurukuririyeho umugisha.
# umugabo wawe uzarindukumuhaga ukuboko kumwe ni ikindi ni ikindi ni we bakinginziraho imitsima wawe
# ----------- temperature:  1.0
# kumwe ni ikindi ni ikindi ni we bakinginziraho imitsima wawe.’
# ikandi uzasetuzano ragerayo kubanyagizwa ngo uwitekase ina amahangu n'agamoro byanywa inkango yawo, uwiteka isize inkuze yumwe n'arezi uko umugisha,
# yosefu arabagira imbere.
# uwitaka kw'imikango inema zanyu, ngiza kuri uwiteka inyana, ini izaharu uhagendoka.
# uwutambire imikana no cumi lamarayu z'abavuye ibisirayeli, ngo imasa bagutur'iye umwenda, azakere amakumyaisi bivukanya kwewe’
# uwiteka
# ----------- temperature:  1.2
# r'iye umwenda, azakere amakumyaisi bivukanya kwewe’
# uwiteka agandi kigindikushikikarize.
# doza ubwaye muzikaziziza ubutaze be.
# aburamu barukeye, binganita n'abantu b'imanagirikinye.
# bakinsiishija, igisiga, umugaboro wafwacyo, tubanyeginture, ngo ukone liteke ija murishinga mu gitozi.
# ubukumbahuruke urugando bwose, ibihe.
# muzelisumugahobire ombibyinz'i” bene mu iminga ijana wa cumi w'ibintu byinsi. ubwingiye mugirokanura ubwaba igihuma iminsi, yose.” zepoch:  18
# Epoch 1/1
# 66647/66647 [==============================] - 29s 435us/step - loss: 1.2979
#
# ---Generating with seed: "o b'abagabo.
# niba atanejeje shebuja wagambiriye kumurongora"
#
# ----------- temperature:  0.2
# o b'abagabo.
# niba atanejeje shebuja wagambiriye kumurongora abonaniro.
# imana irambura inzama zabona.
# aramubwira ati “nda umunsi w'imunani.
# umugabo wase wa sekaye mu gihugu cya egiputa.
# imana irambura uko ari cyo gicaniro impande zo buri ni rumera na shekeli na yosefu.
# nuko uwiteka aramusubiza ati “ni ko ariko umunyegiputa.
# imana iranda ati “ndi wo mu mirwa itatu n'inyanja.
# aramuhanga atande.
# kandi umuntu wawo n'abana bandukanira nawe, nanjye namwe
# ----------- temperature:  0.5
# e.
# kandi umuntu wawo n'abana bandukanira nawe, nanjye namwe nabashura icyango n'inyana.
# kandi ndi ni zo nzagwira nti ‘ni iki gihundu.
# irindwi n'iminsi irangwa igipfa na fera.
# maze mu gihugu cy'i bintu cyawe n'uburebure, ni bo bakora amara ku musozi n'ikingwi.
# uwiteka ari icyo ni cyo uwiteka arindwi nta ‘ni ho ndokera na rureka,
# iri ndi umwe umuntu wese w'inyanja hose n'inyamaswa zose zibanyegipfa n'urubyaro rwawe.
# umuntu wawe nkari zose na yo.
# mukor
# ----------- temperature:  1.0
# ipfa n'urubyaro rwawe.
# umuntu wawe nkari zose na yo.
# mukorwa uburasiranye.’
# muhelea wene semua na farawo ntakanange, na shekeli.
# arapfiya ajyana na disana nabira, ari ko amara gose.’ kuri unuhati wabi,
# nandi umanange nabwo n'abisirayeli n'imbere ye umuntu ucimikaye, kandi nzamosirata ubureka mu butaku. na muri iza no n'akapfina isihayeli na bohe.
# iyo ni yo kurugira na hoso ayono guzakaguma maryanye, adahomo ya farawira,
# nuwire ifite yembura inzuza y
# ----------- temperature:  1.2
# aryanye, adahomo ya farawira,
# nuwire ifite yembura inzuza yuboheye yosefu, ha sodi.nabashyirana abanyezabu, kahemo yanyungiruba.
# “gihireye yomu mukore wo mujye kubyamba ngo nuko, arakibwirira.
# uwiteka amaleka yanyu, shyure ayo ahōrore, nta ditangererero rabwira heneki abisibayeli yarume inzago z'andi nawe n'abunanu.
# banezerahohora ku mujisho. ijwa rihugu ijoro eri mu nyo itanu, uko imitindi?
# moko nanjye nzajya muyonohi. keza, igicu i kamwe.’ ”
# kandi epoch:  19
# Epoch 1/1
# 66647/66647 [==============================] - 30s 446us/step - loss: 3.0635
#
# ---Generating with seed: " ry'ibonaniro, bajye bakaraba boge n'ibirenge badapfa, cyang"
#
# ----------- temperature:  0.2
#  ry'ibonaniro, bajye bakaraba boge n'ibirenge badapfa, cyangwa imb“ha y“““um‘‘““kuri yamwe 5w“tegeka54 m“tuman““n“w““nza“ubwo b‘tuūe butakira imb‘h“““k““uū“n“um‘tera yanjye 54we 5zaba“ibitat““umugaraga imbeūe amara imana y“ mu‘iū“““uū“““k““uwiteka abwira aburamu ar““umutambiro rwawe ruzabwira inzara.“
# uūnta a5wari imbere yamwe mu izi5“t“““““umu‘im“na we 5umuranye mu g“5utanyat“““uūnt‘mu yam“k“ra.
# aburamu aram““uruganir“aho mu “hunz‘ro mu izahabu nzamubwir
# ----------- temperature:  0.5
#
# aburamu aram““uruganir“aho mu “hunz‘ro mu izahabu nzamubwira itsirayo, ntiyagabo rurwe ruby“riūre imber“ we.
# uūnta “mwe uz‘nyu‘‘ūmash“ngar“r4r‘ū“raza“ mu‘m“tuma5ira““tegeka aban““gi5 b5tebaniū“rizi“ ““umutam‘gwa usirayo “umugar5k‘we wo mu isi y“k5 bya5way“ mu izambere 5wanjye nijya mu ““‘“‘‘m‘ze i simb“tw“ r4o““urugabur‘o n“““uū‘n““““kumūza ihereye im““nzo we, n““ny“““ne barabamukara im“nana wa m)“ni ““““5‘ne se “““‘‘umuntu“avas“ngo amahunyu ahite imb5ir
# ----------- temperature:  1.0
# m)“ni ““““5‘ne se “““‘‘umuntu“avas“ngo amahunyu ahite imb5ira ry'abanz“zi5waūo mose n'umwe,“ituro ryose mu rumbyira iūzangi mose5“ū“aū“n“ mw‘iūha m45“5umwe ūz“‘5u abiri mu butay““ubwotu“‘ū“umutware f“raūmereū5 5in““rū‘wo urabwire, ngerw“we uū“hama egaz“ūh““wa mw“kū““w“cūngir““‘‘itanda5u‘‘‘mw5““55“5jururizir“e “i5“n“‘uwi‘na“h‘“n‘mwe na rya mose‘iriri5“t““““‘‘wen“u‘ish“ko “kuri ‘umuko“yana 54we n“aban“‘5wa mos“ wawe ““55timani5, cy'abanyuba. “u‘mwe 5““‘burek
# ----------- temperature:  1.2
# an“‘5wa mos“ wawe ““55timani5, cy'abanyuba. “u‘mwe 5““‘burekariū““dar45 iū‘ū“tir“‘nwuyit‘“h‘dagature imyaka 54e‘mwany““ye ihurag‘5hez), , neho “b‘mbi “osefu abwira5ira “‘‘uw‘im“vu4ūro‘moseūū“““““k‘raū‘nzindiye,““““nzantūre “gukora r“sefu‘n““““tw“ūū“na mbere y4weūza545““imitw“mea4ū“, ama5amy“ū“ūra egeza5ūr) muteza55‘m““““‘‘d‘‘“imura‘‘mu‘n‘ūza, uz‘buūr“h‘vu ū““5iūte umu‘ū“a‘“nkamajye, kubit njirirw“““iūze“na “ga5a‘iri, “kandi uryavugirire‘5““umutwirey“,“s‘‘uepoch:  20
# Epoch 1/1
# 66647/66647 [==============================] - 29s 430us/step - loss: 1.8558
#
# ---Generating with seed: "eli bakanesha, yayamanura abamaleki bakanesha,
# maze amaboko"
#
# ----------- temperature:  0.2
# eli bakanesha, yayamanura abamaleki bakanesha,
# maze amaboko yabyo babaha umugaba we.
# aburahamu arababwira ati “ni icyo babaha umugaba we, na we ari imina ibiti bazakubwirira bataba abakoza baba yabafa babatwe, n'abahamba ba babahanu, n'ubu ruzina n'umugabango umwe wa abo bazajya barabagirira ubutaka bwa ba bakaze bakorera barabakazana na arongo arababwira ati “ni uwiteka abaha imurabu we.
# ibi inshoreze i barasabira bakabaza abahanga bawe n'abahabi n'ibi
# ----------- temperature:  0.5
# nshoreze i barasabira bakabaza abahanga bawe n'abahabi n'ibisirayeli baba abagaragu be bakiriza barapfa, ni iminsi mana zo ku gicaniro ubugiri bibikinze, asama abafabati bababyiba maraye n'abakobwa bawe, kagana atanu barabahaye bakabazabaza ati “imana izababwiza ati “nimubwira bati “imana ibeni batatuba, abamusibaza aburahamu na we ubudore bwabo, n'ibifite ubugingo bwanjye bube mazaye imyaka magana na egiputa, ni icyo gihungu ari uwiteka ibifi bazajyange b
# ----------- temperature:  1.0
# a na egiputa, ni icyo gihungu ari uwiteka ibifi bazajyange bakubyibavu n'umitima wa we.
# “dara imana.
# irabamera beje.
# yokorabiza aramubwira ati “ibyo bwo bibenze kizaha aboni bw'ubushyi mu ihena  na he.
# daraswiburi be, uwiteka ibyo gihugu, ni umushize umuhangwu ko mu nzu yiko ibireho.’
# abana be babo arababwira bakarisha ubwo bubako babyo buwe mu gifirani cyo buko aravuga batao uwo ni kwiza abahandi n'urubantu bw'uk'iringo bibukuranzirwe ntamwizi biba u
# ----------- temperature:  1.2
# handi n'urubantu bw'uk'iringo bibukuranzirwe ntamwizi biba uvukwe” uko abe abavuza ba tebaki ituruzwe, babaha ubadadi bwo mubiri. nanjye kuzinzure izanatu zabo, ngiganwa abahara?
# maze amaburi be, sonyemwo we yabagenzakanye asaba ababaze.
# uwiteka abwira bati “donde ubwo gubyabone, nyina w'amabana na babwira maza i fera ni ubwubira bahaba isirayembiri. iviro uhera cyenganishijweho umugore we. nahora amaze mu z'ibitaru bo bo bubeze bifata byo bwose mukagizaepoch:  21
# Epoch 1/1
# 66647/66647 [==============================] - 29s 438us/step - loss: 1.0640
#
# ---Generating with seed: " yabambyeho ihema rye ayigura na bene hamori, se wa shekemu,"
#
# ----------- temperature:  0.2
#  yabambyeho ihema rye ayigura na bene hamori, se wa shekemu, umwana wanjye ndatatuza umuntu uzabeni umwe muri abana.
# uwiteka abwira mose ati “ni uko abohe bari kumwe na we, kandi abantu bawe uko ari icyigozi itatu ati “no bazirira umwani wose uzabani bw'intama, imana izahaburira.
# aburamu aramusubiza ati “ndatwara, aramubana ati “ndatwira imbere ya farawo.
# uwiteka abwira mose ati “ni uwiteka imana iranira iki gihugu.
# imana irani cya gitore cyose.”
# kand
# ----------- temperature:  0.5
# na iranira iki gihugu.
# imana irani cya gitore cyose.”
# kandi uwo ni iki gihugu cya egiputa.
# isaka na yo mbambo na abindi bishobo umugore utandogoze inzozi abimeli, icyo gihugu cya egiputa cyose ngo uzanikishishe ibitanuro icyo kizamena iri byo nzayo magana inani n'ibintu byase, n'ibi kiza na ryosefu umwe imyaka itatu y'iminsi ijiri, uko ari icyo ngo bibukwirira ingongo za farawo.
# aburamu aramubwira ati “ni ucumi inyongo y'ubureburo n'umuntu umwe ni we u
# ----------- temperature:  1.0
# wira ati “ni ucumi inyongo y'ubureburo n'umuntu umwe ni we ubageya ini we umuherero, kandi bitegendamo iki gihugujcyo uzani, atwari isara na nakumu. tuzabonereza ini ba iheni, izahamyira y'ubwo uwamubwa.”
# tundatugabo.
# uwitekani ibwira mose ati
# “nimugugwika.”
# kandi ibyibaho uzaburaho akagutegetsera, ahamyakazi arayikozi, aho mwende wa umwimbi?” n'ubugori bwo mukandi uti ‘uwiteka inonga ubi imbere ya farawo iki nihugu cy'abani bikwijira uturo twazoba rus
# ----------- temperature:  1.2
# re ya farawo iki nihugu cy'abani bikwijira uturo twazoba ruse.”
# karebo ababose bawo umwe mu gifi cyo yivuganiriro iryo abe icyo gihogi azakiri mo myani mwe irindo gitima imana y'icyonge kiri itanu, <mbimi itatu bose umuya yavuze.
# abikaniririya umugabkburya ibsoryambo, na we ashiza umubāzi wose, uko ni mbacu iringwa.” batahamanaratati abatware, umuharanu nawe. uyagobakutsekaza umwami umwika icamowira n'abana, azahunga kandi bpfati umwe umwami umunyagipatiepoch:  22
# Epoch 1/1
# 66647/66647 [==============================] - 29s 433us/step - loss: 1.0452
#
# ---Generating with seed: "uko ari indwi,
# zimaze kuzirya, ntiwamenya yuko ziziriye, zi"
#
# ----------- temperature:  0.2
# uko ari indwi,
# zimaze kuzirya, ntiwamenya yuko ziziriye, ziburi umugabo wawe ukagira ngo umukobwa we abakwiza bakobo baguruye mu gihugu cya egiputa cyose.
# ibisirayeli bibisi.
# imana yabyari abagaramu n'inyingira inkongo z'umuhundo wanjye n'umurimbwa w'ihamye, akagurukira impfira ya karimu yicu w'i simayo aramubwira ati “ndakwingira izahabu.
# uko abagabo bako umurimba we ati “imana na isaka n'ubusirayeli n'akabwira abaso bene se bakanya bakwiye amasoko yab
# ----------- temperature:  0.5
# irayeli n'akabwira abaso bene se bakanya bakwiye amasoko yabo ari imbere ye baburi baba ikonzi imitsima kikani mugano itanu, kuko umutware yo mu muswire yo kubwira mu midugudu.
# kakobaza impunza zizubiza umugore we mwanjye izahamu ntakabura ataruye yu myaka itatu aburamu arasiba akabura umugisha imana yacu, n'ikigato cyayo giturukira, akari icyo gituma kuko uruka bwa bagaho ngakore ku mutwiro w'abakorera, bakaba abashyira ikingi, kuko amubwira amagambo ata
# ----------- temperature:  1.0
# akorera, bakaba abashyira ikingi, kuko amubwira amagambo atabuja ku mugore w'abakizanuta n'abo nk'uzabyaya inyuma ye abagaragu n'abagiha yakiyuyavuye ibisire.
# kandi nzamukayuva mu rurumu rumwe we ko ari ubwo bw'abasira witwaye imilisho yo mukira yamwe, imana ya so nimubwirira abaraza na sa, bagena imisira yakorerwa ubuginzi, uwiteka, amazira ukubokora we, ubuhareho umubisi, nyida imburo w'abasara turi birindwa, akibikisha yakobo amagoro yo ko kuba icyucur
# ----------- temperature:  1.2
#  turi birindwa, akibikisha yakobo amagoro yo ko kuba icyucuriye hamushuhira kuko nzaje ajyaho asamarira.
# laka yamufisezi akamubwiywejye.
# “nintumamukure warwayishehoene kimukona yaguhira, aranama ala, arekimubishyira ati “dari unyuryemori,
# nikobya yari aho by'umujeseraho.
# umugabo agiputa uw'umudindo, mosi yamwe mose yabyaca cyane cyaya.
# icyo guhugaruriza kugirange n'urwo muture rw'uwo mukombwe cyangwa imalahi.
# abyaramuja isirayu amatuyakija.
# “guhura epoch:  23
# Epoch 1/1
# 66647/66647 [==============================] - 32s 486us/step - loss: 1.0224
#
# ---Generating with seed: "anika iyo nkoni akubitira amazi y'uruzi mu maso ya farawo no"
#
# ----------- temperature:  0.2
# anika iyo nkoni akubitira amazi y'uruzi mu maso ya farawo no ku nkori y'i shimbyi.
# uko uwiteka yari umuntu wese wose n'uburahagwa bari “umunsi w'ibitare by'i bele, ariko imana ibo ni cyo gihugu n'uburori rwa rurayingwa, aburahamu arongera akagurukira, ahuri kuri icyo uwiteka inkingiro, irindwi, kuko ibire byanjye no ku gihugu cy'uwiteka ikirīga, ubureshare by'inkongero kukora.
# kandi uwiteka inyumanire mugire intuma.
# “kandi uzabwire uwiteka ikirīrere kuk
# ----------- temperature:  0.5
# manire mugire intuma.
# “kandi uzabwire uwiteka ikirīrere kukorera kugira ngo bitworereho uburanyaro bwanjye.
# “ndakuri mweze kuzashyirana inyingiro na rikori.
# irindwi ni ihinze nahiguza ibyokurya byose.
# imbere yeri uko uwiteka iri yaryagana inkacya yose, uzajyeye mu gihugu.
# imyaka iri iyo mitwire imbere y'uwiteka inkange zari nowe.”
# kandi uzarize ubwiza bube mukubwa.” uwiteka ishyingiro mukiri nda we, ashizaho ikije indi muringwa, n'ubutora by'i boha,
# ----------- temperature:  1.0
#  nda we, ashizaho ikije indi muringwa, n'ubutora by'i boha, ahuruka kwe, kugira ngo utereza.
# mose na wo ngirishekereza icyagwe, uwiteka cyane.’ hahige y'amose arumbara kujya inture zuba zo kuza, akujyeho kugira ngo utegekere umwe ari yora.
# no atugunyiraho, musozeranire hose, n'icy'ihiriro.
# farawo aburahamu nzoshyweje cyane, nyani nda, ngo nginshye nekereze kwere rumwe.
# uwituka iryo n'imirimono.
# “siryyiye ho hagize inzoza.
# uri ivuraniro, ajya mu butaka
# ----------- temperature:  1.2
# .
# “siryyiye ho hagize inzoza.
# uri ivuraniro, ajya mu butaka.
# kurimenyerezeza we.
# yondiye kuzabyo n'urwo rwo.
# uwiteka impande ihere.
# yosefu yamaze imyensirse nyinsha, mpelereze umunese mwene ne ebohe, irwibe muri we ngebo.
# kandi ikobore we, kukoreho kuri isezaranka.
# rebi anyungeroho, ajya aho yakobora.”
# sakaja i berubuvuzi, icyose kizagazira.
# asuhotseze mwene yeredi, ahugudukamukaja.”
# wene datwe ubukagizi, kukorihererera mu izuhatwa.
# usugeze izavepoch:  24
# Epoch 1/1
# 66647/66647 [==============================] - 30s 451us/step - loss: 0.9903
#
# ---Generating with seed: "izabura kubagenderera, namwe muzajyane amagufwa yanjye, muya"
#
# ----------- temperature:  0.2
# izabura kubagenderera, namwe muzajyane amagufwa yanjye, muyaguru n'ubugingo bwanjye burakira inkango y'umuntu uruhemo rwa muri wo kuko isanana na mirongo itatu na bo ari ni imana isabanu, mukoreranye na we na yoshira mu bitambo, umuntu wese ari wo ntabahamba amarambo yacu aramubwira ati “uwiteka ari bu ba mu nzu ya yosefu yamuranga batwarema ibihe byose n'inkandi yinsi y'imbere y'uwo muntu abona imyaka ijana na yakobo na yosheba.
# aburamu aramba arongo ara
# ----------- temperature:  0.5
# myaka ijana na yakobo na yosheba.
# aburamu aramba arongo aramuba arabahobora aramuha umuntu wese abantu basabira mu myambaro yose n'ingambi izahande n'umuntu urunda kandi mwene ruzabyo zinshije umurimba w'ihongo, abona yuba yarabyaramonikani nawa, naba mu mitwa yakobo ari ni mu isi, yabonera mu musozi w'umuhungu wa we. no ku bandi bo buturo byanyu byari umuntu wese uruboro rwa yo ndi umuntu zakora nk'uko uwiteka yatuye umugobwa wa karimo, aburahamu aramusu
# ----------- temperature:  1.0
#  nk'uko uwiteka yatuye umugobwa wa karimo, aburahamu aramusubiza bati “i bombo.’
# ari ni isi cyane ari baraemo ya sawumbo yabo, ndabatunge basaburayo, kakoboraho.” uwiteka ane mwene so ni ho nowa wabose nguziriye kubashyira mu isi, ko umuhebiro muny
# ----------------------------------------------------------
# KeyboardInterrupt        Traceback (most recent call last)
# <ipython-input-12-ce5996898f35> in <module>()
#      16                 sampled[0, t, char_indices[char]] = 1.
#      17
# ---> 18             preds = model.predict(sampled, verbose=0)[0]
#      19             next_index = sample(preds, temperature)
#      20             next_char = chars[next_index]
#
# ~/anaconda3/envs/dl-gpu/lib/python3.6/site-packages/keras/models.py in predict(self, x, batch_size, verbose)
#     937         if not self.built:
#     938             self.build()
# --> 939         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     940
#     941     def predict_on_batch(self, x):
#
# ~/anaconda3/envs/dl-gpu/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1746         f = self.predict_function
#    1747         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1748                                   verbose=verbose, steps=steps)
#    1749
#    1750     def train_on_batch(self, x, y,
#
# ~/anaconda3/envs/dl-gpu/lib/python3.6/site-packages/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1297                 else:
#    1298                     ins_batch = _slice_arrays(ins, batch_ids)
# -> 1299                 batch_outs = f(ins_batch)
#    1300                 if not isinstance(batch_outs, list):
#    1301                     batch_outs = [batch_outs]
#
# ~/anaconda3/envs/dl-gpu/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2330         updated = session.run(self.outputs + [self.updates_op],
#    2331                               feed_dict=feed_dict,
# -> 2332                               **self.session_kwargs)
#    2333         return updated[:len(self.outputs)]
#    2334
#
# ~/anaconda3/envs/dl-gpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/dl-gpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# ~/anaconda3/envs/dl-gpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/envs/dl-gpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/dl-gpu/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic. With higher temperatures, the generated text becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible. With a high temperature, the local structure starts breaking down and most words look like semi-random strings of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# - We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# - In the case of text, such a model is called a "language model" and could be based on either words or characters.
# - Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# - One way to handle this is the notion of softmax temperature. Always experiment with different temperatures to find the "right" one.
