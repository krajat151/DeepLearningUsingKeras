# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#The-IMDB-dataset" data-toc-modified-id="The-IMDB-dataset-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>The IMDB dataset</a></span></li><li><span><a href="#Loading-the-IMDB-dataset" data-toc-modified-id="Loading-the-IMDB-dataset-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Loading the IMDB dataset</a></span><ul class="toc-item"><li><span><a href="#Sample-on-how-to-decode-reviews-back-to-English-words" data-toc-modified-id="Sample-on-how-to-decode-reviews-back-to-English-words-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Sample on how to decode reviews back to English words</a></span></li></ul></li><li><span><a href="#Preparing-the-data" data-toc-modified-id="Preparing-the-data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Preparing the data</a></span><ul class="toc-item"><li><span><a href="#One-hot-Encoding-the-integer-sequences-into-a-binary-matrix" data-toc-modified-id="One-hot-Encoding-the-integer-sequences-into-a-binary-matrix-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>One-hot Encoding the integer sequences into a binary matrix</a></span></li></ul></li><li><span><a href="#Building-the-network" data-toc-modified-id="Building-the-network-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Building the network</a></span><ul class="toc-item"><li><span><a href="#The-model-definition" data-toc-modified-id="The-model-definition-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>The model definition</a></span></li><li><span><a href="#Compiling-the-model" data-toc-modified-id="Compiling-the-model-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Compiling the model</a></span></li></ul></li><li><span><a href="#Validating-our-approach" data-toc-modified-id="Validating-our-approach-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Validating our approach</a></span></li><li><span><a href="#Training-the-model" data-toc-modified-id="Training-the-model-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Training the model</a></span></li><li><span><a href="#Plotting-the-training-and-validation-loss" data-toc-modified-id="Plotting-the-training-and-validation-loss-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Plotting the training and validation loss</a></span></li><li><span><a href="#Plotting-the-training-and-validation-accuracy" data-toc-modified-id="Plotting-the-training-and-validation-accuracy-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Plotting the training and validation accuracy</a></span></li><li><span><a href="#Retraining-the-model-from-scratch" data-toc-modified-id="Retraining-the-model-from-scratch-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Retraining the model from scratch</a></span></li><li><span><a href="#Further-Experiments" data-toc-modified-id="Further-Experiments-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Further Experiments</a></span><ul class="toc-item"><li><span><a href="#Hidden-Layers" data-toc-modified-id="Hidden-Layers-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Hidden Layers</a></span><ul class="toc-item"><li><span><a href="#One-Hidden-layer" data-toc-modified-id="One-Hidden-layer-11.1.1"><span class="toc-item-num">11.1.1&nbsp;&nbsp;</span>One Hidden layer</a></span></li><li><span><a href="#Four-Hidden-Layers" data-toc-modified-id="Four-Hidden-Layers-11.1.2"><span class="toc-item-num">11.1.2&nbsp;&nbsp;</span>Four Hidden Layers</a></span></li></ul></li><li><span><a href="#Hidden-Units" data-toc-modified-id="Hidden-Units-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Hidden Units</a></span><ul class="toc-item"><li><span><a href="#32-hidden-Units" data-toc-modified-id="32-hidden-Units-11.2.1"><span class="toc-item-num">11.2.1&nbsp;&nbsp;</span>32 hidden Units</a></span></li><li><span><a href="#64-hidden-Units" data-toc-modified-id="64-hidden-Units-11.2.2"><span class="toc-item-num">11.2.2&nbsp;&nbsp;</span>64 hidden Units</a></span></li></ul></li><li><span><a href="#Loss-Function" data-toc-modified-id="Loss-Function-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Loss Function</a></span><ul class="toc-item"><li><span><a href="#Mean-Square-Error" data-toc-modified-id="Mean-Square-Error-11.3.1"><span class="toc-item-num">11.3.1&nbsp;&nbsp;</span><code>Mean Square Error</code></a></span></li></ul></li><li><span><a href="#Activation-Function" data-toc-modified-id="Activation-Function-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>Activation Function</a></span><ul class="toc-item"><li><span><a href="#tanh" data-toc-modified-id="tanh-11.4.1"><span class="toc-item-num">11.4.1&nbsp;&nbsp;</span><code>tanh</code></a></span></li><li><span><a href="#selu" data-toc-modified-id="selu-11.4.2"><span class="toc-item-num">11.4.2&nbsp;&nbsp;</span><code>selu</code></a></span></li></ul></li><li><span><a href="#Regularization" data-toc-modified-id="Regularization-11.5"><span class="toc-item-num">11.5&nbsp;&nbsp;</span>Regularization</a></span><ul class="toc-item"><li><span><a href="#Version-of-the-model-with-lower-capacity" data-toc-modified-id="Version-of-the-model-with-lower-capacity-11.5.1"><span class="toc-item-num">11.5.1&nbsp;&nbsp;</span>Version of the model with lower capacity</a></span></li><li><span><a href="#Version-of-the-model-with-higher-capacity" data-toc-modified-id="Version-of-the-model-with-higher-capacity-11.5.2"><span class="toc-item-num">11.5.2&nbsp;&nbsp;</span>Version of the model with higher capacity</a></span></li><li><span><a href="#Adding-L2-Weight-regularization-to-the-model" data-toc-modified-id="Adding-L2-Weight-regularization-to-the-model-11.5.3"><span class="toc-item-num">11.5.3&nbsp;&nbsp;</span>Adding L2 Weight regularization to the model</a></span></li><li><span><a href="#Dropout" data-toc-modified-id="Dropout-11.5.4"><span class="toc-item-num">11.5.4&nbsp;&nbsp;</span>Dropout</a></span></li></ul></li></ul></li><li><span><a href="#Key-Takeaways" data-toc-modified-id="Key-Takeaways-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Key Takeaways</a></span></li></ul></div>

# %% [markdown]
# # Goal
# In this example, we classify movie reviews as positive or negative, based on the text content of the reviews.

# %% [markdown]
# # The IMDB dataset

# %% [markdown]
# - The IMDB dataset comes packaged with Keras. It has already been preprocessed:
#   - The reviews(sequences of words) have been turned into sequence of integers, where each integer stands for a specific word in a dictionary.

# %% [markdown]
# - This is a set of  **50,000** highly polarized reviews from the Internet Movie Database.
#   - They are split into **25,000** reviews for both training and **25,000** reviews for testing.
#   - Each set consists of $50\%$ negative and $50\%$ positive reviews.

# %% [markdown]
# # Loading the IMDB dataset

# %%
from keras.datasets import imdb
# Out:
# Using TensorFlow backend.

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

# %% [markdown]
# The argument ```num_words=10000``` means you will only keep the top 10,000 most frequently occuring words in the training data. Rare words will be discarded. This allows us to work with vector data of manageable size.

# %%
print(train_data[0])
# Out:
# [1, 13, 197, 12, 16, 31, 7, 4, 118, 2289, 13, 28, 110, 11, 6, 137, 518, 13, 421, 17, 151, 13, 62, 43, 181, 294, 8, 783, 2, 880, 125, 7, 4, 616, 105, 16, 530, 12, 16, 141, 6, 73, 224, 20, 15, 25, 71, 654, 54, 38, 5, 38, 1131, 61, 64, 439, 16, 11, 49, 139, 12, 610, 40, 294, 19, 6, 344, 370, 16, 1423, 12, 5, 12, 16, 916, 6297, 3249, 9, 1036, 33, 222, 11, 61, 652, 5, 29, 16, 321, 11, 4, 217, 17, 3006, 2, 530, 20]

# %%
train_labels[0]
# Out:
# 1

# %% [markdown]
# - Each review is a list of word indices (encoding a sequence of words).
# - Labels are lists of 0s and 1s, where 0 stands for **negative** and 1 stands for **positive**.

# %% [markdown]
# - Because we are restricting ourselves to the top 10, 000 most frequent words, no word index will exceed 10, 000:

# %%
# %%time
max([max(sequence) for sequence in train_data])
# Out:
# CPU times: user 148 ms, sys: 4 ms, total: 152 ms
# Wall time: 148 ms
# 9999

# %% [markdown]
# ## Sample on how to decode reviews back to English words

# %%
word_index = imdb.get_word_index()

# %% [markdown]
# - word_index is a dictionary mapping words to an integer index.

# %%
reverse_word_index = dict(
    [(value, key) for (key, value) in word_index.items()])

# %% [markdown]
# - Reverses it, mapping integer indices to words.

# %%
decoded_review = ' '.join(
    [reverse_word_index.get( i - 3, '?') for i in train_data[0]])

# %% [markdown]
# - Decodes the review. Note that the indices are offset by 3 because 0, 1, and 2 are reversed indices for *padding*, *start* of sequence, and *unknown*.

# %%
decoded_review
# Out:
# '? i thought it was one of the best sequels i have seen in a while sometimes i felt as though i would just want someone to die ? killing off of the annoying characters was brilliant it was such a well done movie that you were happy when so and so died my only problem was in some scenes it looked like someone with a home camera was filming it and it was weird judd nelson is cute at least in my opinion and he was excellent in the role as stanley ? brilliant movie'

# %% [markdown]
# # Preparing the data

# %% [markdown]
# - You can't feed lists of integers into a neural network. You have to turn your lists into tensors. There so tat  are two ways to do that:
#  1. Pad your lists so that they all have the same length, turn them into an integer tensor of shape ```(samples, word_indices)```, and then use as the first layer in your network a layer capable of handling such integer tensors (e.g : **[The Embedding layer](https://keras.io/layers/embeddings/)** ).
#  2. One-hot encode your lists to turn them into vectors of 0s and 1s. This would mean, for instance, turning the sequence ```[3, 5]``` into a 10, 000-dimensional vector that would be all 0s except for indices 3, and 5, which would be 1s. Then you could use as the first layer in your network a **Dense** layer, capable of handling floating-point vector data.

# %% [markdown]
# ## One-hot Encoding the integer sequences into a binary matrix

# %%
import numpy as np

# %%
def vectorize_sequences(sequences, dimension=10000):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1. # Sets specific indices of results[i] to 1s
    return results

# %%
x_train = vectorize_sequences(train_data)  # vectorized training data
x_test  = vectorize_sequences(test_data)   # vectorized testing data

# %%
x_train[0]
# Out:
# array([ 0.,  1.,  1., ...,  0.,  0.,  0.])

# %%
x_train.shape
# Out:
# (25000, 10000)

# %% [markdown]
# - Vectorize the labels, which is straightforward:

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test  = np.asarray(test_labels).astype('float32')

# %%
y_train[0]
# Out:
# 1.0

# %% [markdown]
# Now the data is ready to be fed into a neural network.

# %% [markdown]
# # Building the network

# %% [markdown]
# For time being, our network will have:
# - 2 intermediate layers with 16 hidden units each.
# - A third layer that will output the scalar prediction regarding the sentiment of the current review.

# %% [markdown]
# The intermediate layers will use ```relu``` as their activation function, and the final layer will use a sigmoid activation function so as to output a probability score.

# %% [markdown]
# ## The model definition

# %%
from keras import models
from keras import layers

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %% [markdown]
# Finally, we need to choose a loss function and an optimizer. Because we are facing a binary classification problem and the output of our network is a probability (we end our network with a single-unit layer with a sigmoid activation), it is best to use the **```binary_crossentropy```** loss.
#
# It is not the only viable choice: We could use, for instance, **```mean_squared_error```**. But crossentropy is usually the best choice when you are dealing with models that output probabilities.
#
# Crossentropy is a quantity from the field of Information Theory that measures the distance between probability distributions or, in this case, between the ground-truth distribution and our predictions.

# %% [markdown]
# ## Compiling the model

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Validating our approach

# %% [markdown]
# - Create a validation set by setting apart 10, 000 samples from the original training data.

# %%
x_val = x_train[:10000]

# %%
partial_x_train = x_train[10000:]

# %%
y_val = y_train[:10000]

# %%
partial_y_train = y_train[10000:]

# %% [markdown]
# # Training the model

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 20,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# 15000/15000 [==============================] - 10s 661us/step - loss: 0.5024 - acc: 0.7745 - val_loss: 0.3590 - val_acc: 0.8761
# Epoch 2/20
# 15000/15000 [==============================] - 3s 218us/step - loss: 0.2883 - acc: 0.9026 - val_loss: 0.2917 - val_acc: 0.8889
# Epoch 3/20
# 15000/15000 [==============================] - 4s 238us/step - loss: 0.2096 - acc: 0.9285 - val_loss: 0.2749 - val_acc: 0.8903
# Epoch 4/20
# 15000/15000 [==============================] - 4s 236us/step - loss: 0.1640 - acc: 0.9467 - val_loss: 0.2877 - val_acc: 0.8857
# Epoch 5/20
# 15000/15000 [==============================] - 3s 232us/step - loss: 0.1369 - acc: 0.9567 - val_loss: 0.2925 - val_acc: 0.8831
# Epoch 6/20
# 15000/15000 [==============================] - 3s 228us/step - loss: 0.1127 - acc: 0.9638 - val_loss: 0.3030 - val_acc: 0.8849
# Epoch 7/20
# ...

# %% [markdown]
# # Plotting the training and validation loss

# %%
history_dict = history.history

# %%
history_dict.keys()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

# %%
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']

# %%
epochs = range(1, len(acc_values) + 1)
epochs
# Out:
# range(1, 21)

# %%
plt.plot(epochs, loss_values, 'b', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Plotting the training and validation accuracy

# %%
plt.plot(epochs, acc_values, 'b', label='Training accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# - The training loss decreases with every epoch, and the training accuracy increases with every epoch.
# - But that is not the case for the validation loss and accuracy: they seem to peak at the **4th** epoch. This is an example of **overfitting**: after the second epoch, we are overoptimizing on the training data, and we end up learning representations that are specific to the training data and don't generalize to data outside the training set.
#
# - In this case, to prevent overfitting, we could stop training after three epochs.

# %% [markdown]
# # Retraining the model from scratch

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
model.fit(x_train, y_train, epochs=3, batch_size=512)
# Out:
# Epoch 1/3
# 25000/25000 [==============================] - 4s 140us/step - loss: 0.4584 - acc: 0.8072
# Epoch 2/3
# 25000/25000 [==============================] - 4s 145us/step - loss: 0.2586 - acc: 0.9102
# Epoch 3/3
# 25000/25000 [==============================] - 4s 143us/step - loss: 0.2005 - acc: 0.9290
# CPU times: user 5.02 s, sys: 6.22 s, total: 11.2 s
# Wall time: 10.9 s

# %%
results = model.evaluate(x_test, y_test)
# Out:
# 25000/25000 [==============================] - 3s 134us/step

# %%
results
# Out:
# [0.2827775570011139, 0.88739999999999997]

# %% [markdown]
# This fairly naive approach achieves an accuracy of $88\%$.

# %% [markdown]
# # Further Experiments

# %% [markdown]
# ## Hidden Layers

# %% [markdown]
# ### One Hidden layer

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 4s 246us/step - loss: 0.4988 - acc: 0.7902 - val_loss: 0.3769 - val_acc: 0.8751
# Epoch 2/5
# 15000/15000 [==============================] - 3s 219us/step - loss: 0.3087 - acc: 0.9035 - val_loss: 0.3238 - val_acc: 0.8762
# Epoch 3/5
# 15000/15000 [==============================] - 4s 238us/step - loss: 0.2377 - acc: 0.9251 - val_loss: 0.2857 - val_acc: 0.8911
# Epoch 4/5
# 15000/15000 [==============================] - 4s 248us/step - loss: 0.1955 - acc: 0.9398 - val_loss: 0.2772 - val_acc: 0.8902
# Epoch 5/5
# 15000/15000 [==============================] - 3s 232us/step - loss: 0.1659 - acc: 0.9496 - val_loss: 0.2740 - val_acc: 0.8903
# CPU times: user 7.88 s, sys: 10.4 s, total: 18.3 s
# Wall time: 17.9 s

# %%
def plot_history(history):
    history_dict = history.history
    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']
    acc_values = history_dict['acc']
    val_acc_values = history_dict['val_acc']
    epochs = range(1, len(acc_values) + 1)
    
    plt.plot(epochs, loss_values, 'b', label='Training loss')
    plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
    plt.title('Training and Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    plt.plot(epochs, acc_values, 'b', label='Training accuracy')
    plt.plot(epochs, val_acc_values, 'r', label='Validation accuracy')
    plt.title('Training and Validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
plot_history(history)

# %% [markdown]
# ### Four Hidden Layers

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 4s 240us/step - loss: 0.5303 - acc: 0.7669 - val_loss: 0.4131 - val_acc: 0.8335
# Epoch 2/5
# 15000/15000 [==============================] - 4s 237us/step - loss: 0.3096 - acc: 0.8978 - val_loss: 0.3024 - val_acc: 0.8887
# Epoch 3/5
# 15000/15000 [==============================] - 3s 229us/step - loss: 0.2216 - acc: 0.9247 - val_loss: 0.2804 - val_acc: 0.8906
# Epoch 4/5
# 15000/15000 [==============================] - 3s 221us/step - loss: 0.1704 - acc: 0.9448 - val_loss: 0.2939 - val_acc: 0.8855
# Epoch 5/5
# 15000/15000 [==============================] - 3s 219us/step - loss: 0.1345 - acc: 0.9566 - val_loss: 0.3019 - val_acc: 0.8845
# CPU times: user 7.84 s, sys: 10.1 s, total: 17.9 s
# Wall time: 17.5 s

# %%
plot_history(history)

# %% [markdown]
# ## Hidden Units

# %% [markdown]
# ### 32 hidden Units

# %%
model = models.Sequential()
model.add(layers.Dense(32, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 4s 235us/step - loss: 0.4798 - acc: 0.7803 - val_loss: 0.3259 - val_acc: 0.8853
# Epoch 2/5
# 15000/15000 [==============================] - 3s 225us/step - loss: 0.2594 - acc: 0.9090 - val_loss: 0.2904 - val_acc: 0.8866
# Epoch 3/5
# 15000/15000 [==============================] - 3s 233us/step - loss: 0.1971 - acc: 0.9289 - val_loss: 0.2780 - val_acc: 0.8905
# Epoch 4/5
# 15000/15000 [==============================] - 4s 244us/step - loss: 0.1481 - acc: 0.9483 - val_loss: 0.2918 - val_acc: 0.8889
# Epoch 5/5
# 15000/15000 [==============================] - 4s 246us/step - loss: 0.1232 - acc: 0.9579 - val_loss: 0.3038 - val_acc: 0.8888
# CPU times: user 8.14 s, sys: 10.4 s, total: 18.5 s
# Wall time: 18.1 s

# %%
plot_history(history)

# %% [markdown]
# ### 64 hidden Units

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 4s 272us/step - loss: 0.4811 - acc: 0.7727 - val_loss: 0.5101 - val_acc: 0.7638
# Epoch 2/5
# 15000/15000 [==============================] - 4s 252us/step - loss: 0.2638 - acc: 0.9006 - val_loss: 0.2966 - val_acc: 0.8800
# Epoch 3/5
# 15000/15000 [==============================] - 4s 239us/step - loss: 0.1956 - acc: 0.9271 - val_loss: 0.2898 - val_acc: 0.8852
# Epoch 4/5
# 15000/15000 [==============================] - 3s 233us/step - loss: 0.1438 - acc: 0.9497 - val_loss: 0.3207 - val_acc: 0.8765
# Epoch 5/5
# 15000/15000 [==============================] - 4s 237us/step - loss: 0.1061 - acc: 0.9636 - val_loss: 0.3516 - val_acc: 0.8750
# CPU times: user 8.96 s, sys: 10 s, total: 19 s
# Wall time: 18.7 s

# %%
plot_history(history)

# %% [markdown]
# ## Loss Function

# %% [markdown]
# ### ```Mean Square Error```

# %%
model = models.Sequential()
model.add(layers.Dense(32, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='mse',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 4s 244us/step - loss: 0.1656 - acc: 0.7816 - val_loss: 0.1093 - val_acc: 0.8800
# Epoch 2/5
# 15000/15000 [==============================] - 3s 232us/step - loss: 0.0847 - acc: 0.9075 - val_loss: 0.1084 - val_acc: 0.8526
# Epoch 3/5
# 15000/15000 [==============================] - 3s 225us/step - loss: 0.0621 - acc: 0.9277 - val_loss: 0.0834 - val_acc: 0.8903
# Epoch 4/5
# 15000/15000 [==============================] - 3s 222us/step - loss: 0.0472 - acc: 0.9473 - val_loss: 0.0869 - val_acc: 0.8830
# Epoch 5/5
# 15000/15000 [==============================] - 3s 227us/step - loss: 0.0361 - acc: 0.9613 - val_loss: 0.0882 - val_acc: 0.8813
# CPU times: user 7.83 s, sys: 10.2 s, total: 18 s
# Wall time: 17.6 s

# %%
plot_history(history)

# %% [markdown]
# ## Activation Function

# %% [markdown]
# ### ```tanh```

# %%
model = models.Sequential()
model.add(layers.Dense(32, activation='tanh', input_shape=(10000, )))
model.add(layers.Dense(32, activation='tanh'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 4s 244us/step - loss: 0.4611 - acc: 0.7920 - val_loss: 0.3957 - val_acc: 0.8212
# Epoch 2/5
# 15000/15000 [==============================] - 3s 229us/step - loss: 0.2437 - acc: 0.9073 - val_loss: 0.3019 - val_acc: 0.8738
# Epoch 3/5
# 15000/15000 [==============================] - 4s 243us/step - loss: 0.1647 - acc: 0.9392 - val_loss: 0.4006 - val_acc: 0.8522
# Epoch 4/5
# 15000/15000 [==============================] - 3s 233us/step - loss: 0.1302 - acc: 0.9525 - val_loss: 0.3302 - val_acc: 0.8805
# Epoch 5/5
# 15000/15000 [==============================] - 3s 225us/step - loss: 0.0998 - acc: 0.9647 - val_loss: 0.4489 - val_acc: 0.8595
# CPU times: user 8.06 s, sys: 10.1 s, total: 18.2 s
# Wall time: 17.8 s

# %%
plot_history(history)

# %% [markdown]
# ### ```selu```

# %%
model = models.Sequential()
model.add(layers.Dense(32, activation='selu', input_shape=(10000, )))
model.add(layers.Dense(32, activation='selu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 5,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/5
# 15000/15000 [==============================] - 4s 255us/step - loss: 0.4667 - acc: 0.7890 - val_loss: 0.3206 - val_acc: 0.8720
# Epoch 2/5
# 15000/15000 [==============================] - 3s 232us/step - loss: 0.2408 - acc: 0.9087 - val_loss: 0.2837 - val_acc: 0.8814
# Epoch 3/5
# 15000/15000 [==============================] - 4s 242us/step - loss: 0.1678 - acc: 0.9377 - val_loss: 0.2932 - val_acc: 0.8849
# Epoch 4/5
# 15000/15000 [==============================] - 3s 229us/step - loss: 0.1415 - acc: 0.9470 - val_loss: 0.3290 - val_acc: 0.8803
# Epoch 5/5
# 15000/15000 [==============================] - 3s 227us/step - loss: 0.1143 - acc: 0.9592 - val_loss: 0.3390 - val_acc: 0.8829
# CPU times: user 8.32 s, sys: 10 s, total: 18.4 s
# Wall time: 18 s

# %%
plot_history(history)

# %% [markdown]
# ## Regularization

# %% [markdown]
# ### Version of the model with lower capacity

# %%
model = models.Sequential()
model.add(layers.Dense(4, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(4, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history_lower_cap = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 20,
                    batch_size = 512,
                    validation_data = (x_val, y_val), verbose=0)
# Out:
# CPU times: user 57.9 s, sys: 13.6 s, total: 1min 11s
# Wall time: 1min 15s

# %%
def plot_hist_compare(hist2=None, hist3=None, hist1=history_dict):
    # Original model
    original_loss_values = hist1['loss']
    original_val_loss_values = hist1['val_loss']
    epochs = range(1, len(original_val_loss_values) + 1)
    
    if hist2 is not None:
        
        plt.plot(epochs, original_val_loss_values, 'b', label='Original model')
        smaller_val_loss_values = hist2.history['val_loss']
        plt.plot(epochs, smaller_val_loss_values, 'r', label='Smaller model')
        
        if hist3 is not None:
            larger_val_loss_values = hist3.history['val_loss']
            plt.plot(epochs, larger_val_loss_values, 'g', label='Larger model')
    plt.title('Validation Losses')
    plt.xlabel('Epochs')
    plt.ylabel('Validation loss')
    plt.legend()
    plt.show()

# %%
plot_hist_compare(hist2=history_lower_cap)

# %% [markdown]
# ### Version of the model with higher capacity

# %%
model = models.Sequential()
model.add(layers.Dense(512, activation='relu', input_shape=(10000, )))
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# %%time 
history_higher_cap = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 20,
                    batch_size = 512,
                    validation_data = (x_val, y_val), verbose=0)
# Out:
# CPU times: user 53 s, sys: 12.4 s, total: 1min 5s
# Wall time: 1min 8s

# %%
plot_hist_compare(hist2=history_lower_cap, hist3=history_higher_cap)

# %% [markdown]
# - The smaller network starts overfitting later than the reference network (after 8 epochs rather than four), and its performance degrades more slowly once it starts overfitting.
# - The bigger network starts overfitting almost immediately, after just one epoch, and it overfits more severely. Its validation loss is also noisier.

# %% [markdown]
# ### Adding L2 Weight regularization to the model

# %%
from keras import regularizers

# %%
model = models.Sequential()
model.add(layers.Dense(16, kernel_regularizer=regularizers.l2(0.001),
                       activation='relu', input_shape=(10000, )))
model.add(layers.Dense(16, kernel_regularizer=regularizers.l2(0.001),
                       activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ```l2(0.001)``` means every coefficient in the weight matrix of the layer will add ```0.001 * weight_coefficient_value``` to the total loss of the network. Note that because this penalty is only added at training time, the loss for this network will be much higher at training than at test time.

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 20,
                    batch_size = 512,
                    validation_data = (x_val, y_val), verbose=0)

# %%
def plot_hist_compare(hist2=None, label2 = '',hist1=history_dict):
    # Original model
    original_loss_values = hist1['loss']
    original_val_loss_values = hist1['val_loss']
    epochs = range(1, len(original_val_loss_values) + 1)
    
    if hist2 is not None:
        
        plt.plot(epochs, original_val_loss_values, 'b', label='Original model')
        smaller_val_loss_values = hist2.history['val_loss']
        plt.plot(epochs, smaller_val_loss_values, 'r', label=label2)
        
    plt.title('Validation Losses')
    plt.xlabel('Epochs')
    plt.ylabel('Validation loss')
    plt.legend()
    plt.show()

# %%
plot_hist_compare(hist2=history, label2 = 'L2-regularized model')

# %% [markdown]
# ### Dropout

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 20,
                    batch_size = 512,
                    validation_data = (x_val, y_val), verbose=0)

# %%
plot_hist_compare(hist2=history, label2 = 'Dropout-regularized model')

# %% [markdown]
# # Key Takeaways

# %% [markdown]
# 1. You usually need to do quite a bit of preprocessing on your raw data in order to be able to feed it--as tensors-- into a neural network. Sequences of words can be encoded as binary vectors, but there are other encoding options, too.
# 2. Stacks of **Dense** layers with **relu** activation can solve a wide range of problems (including sentiment classification), and you will likely use them frequently.
# 3. In a binary classification problem (two output classes), your network should end with a Dense layer with one unit and a sigmoid activation: the output of your network should be a scalar between 0 and 1, encoding a probability.
# 4. With such a scalar sigmoid output on a binary classification, the loss function you should use is **binary_crossentropy**.
# 5.  The **rmsprop** optimizer is generally a good choice, whatever your problem. That is one less thing to worry about.
# 6. As they get better at their training data, neural networks eventually start over-fitting and end up obtaining increasingly worse results on data they have never seen before.

# %%
# %load_ext version_information
# %version_information keras, numpy, matplotlib
# Out:
# Software versions
# Python 3.6.3 64bit [GCC 4.8.2 20140120 (Red Hat 4.8.2-15)]
# IPython 6.2.1
# OS Linux 4.4.0 53 generic x86_64 with debian stretch sid
# keras 2.0.9
# numpy 1.12.1
# matplotlib 2.0.0
# Sat Dec 16 19:01:17 2017 CST
